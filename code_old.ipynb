# %% [markdown]
# <a href="https://www.kaggle.com/code/hasibalmuzdadid/customer-personality-analysis-segmentation?scriptVersionId=112570504" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Customer Personality Analysis & Segmentation</p>
#
# <p style="text-align:center; ">
# <img src="https://www.segmentify.com/wp-content/uploads/2021/08/Top-Customer-Segmentation-Examples-every-Marketer-Needs-to-Know.png" style='width: 650px; height: 350px;'>
# </p>
#
# <p style="text-align:justify; ">
# <B>Customer segmentation</B> is the process of separating customers into groups based on the certain traits they share.
#
# Segmentation offers a simple way of organizing and managing company’s relationships with customers. This process also makes it easy to tailor and personalize company’s marketing, service, and sales efforts to the needs of specific groups. This helps to boost customer loyalty and conversions.
# </p>
#
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:130%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Table Of Contents</p>
#
#
#
# |No  | Contents |No  | Contents  |
# |:---| :---     |:---| :----     |
# |1   | [<font color="#682F2F"> Importing Libraries</font>](#1)                   |7   | [<font color="#682F2F"> Digging Deeper</font>](#7)                 |
# |2   | [<font color="#682F2F"> About Dataset</font>](#2)                         |8   | [<font color="#682F2F"> Correlation Map</font>](#8)   |
# |3   | [<font color="#682F2F"> Basic Exploration</font>](#3)                     |9  | [<font color="#682F2F"> Dimensionality Reduction</font>](#9)|
# |4   | [<font color="#682F2F"> Dataset Summary</font>](#4)                       |10  | [<font color="#682F2F"> Customer Segmentation</font>](#10)   |
# |5   | [<font color="#682F2F"> Data Preprocessing</font>](#5)      |11  | [<font color="#682F2F"> Customer's Cluster Profiling</font>](#11)    |
# |6   | [<font color="#682F2F"> Custom Palette For Visualization</font>](#6)              |12  | [<font color="#682F2F"> Thank You</font>](#12)  |

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Importing Libraries</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering
from yellowbrick.cluster import KElbowVisualizer

import warnings
warnings.filterwarnings('ignore')


from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">About Dataset</p>

# %% [markdown]
# **The dataset is provided by Dr. Omar Romero-Hernandez.**
#
# * **ID:** Customer's unique identifier
# * **Year_Birth:** Customer's birth year
# * **Education:** Customer's education level
# * **Marital_Status:** Customer's marital status
# * **Income:** Customer's yearly household income
# * **Kidhome:** Number of children in customer's household
# * **Teenhome:** Number of teenagers in customer's household
# * **Dt_Customer:** Date of customer's enrollment with the company
# * **Recency:** Number of days since customer's last purchase
# * **Complain:** 1 if the customer complained in the last 2 years, 0 otherwise
# * **MntWines:** Amount spent on wine in last 2 years
# * **MntFruits:** Amount spent on fruits in last 2 years
# * **MntMeatProducts:** Amount spent on meat in last 2 years
# * **MntFishProducts:** Amount spent on fish in last 2 years
# * **MntSweetProducts:** Amount spent on sweets in last 2 years
# * **MntGoldProds:** Amount spent on gold in last 2 years
# * **NumDealsPurchases:** Number of purchases made with a discount
# * **AcceptedCmp1:** 1 if customer accepted the offer in the 1st campaign, 0 otherwise
# * **AcceptedCmp2:** 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
# * **AcceptedCmp3:** 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
# * **AcceptedCmp4:** 1 if customer accepted the offer in the 4th campaign, 0 otherwise
# * **AcceptedCmp5:** 1 if customer accepted the offer in the 5th campaign, 0 otherwise
# * **Response:** 1 if customer accepted the offer in the last campaign, 0 otherwise
# * **NumWebPurchases:** Number of purchases made through the company’s website
# * **NumCatalogPurchases:** Number of purchases made using a catalogue
# * **NumStorePurchases:** Number of purchases made directly in stores
# * **NumWebVisitsMonth:** Number of visits to company’s website in the last month

# %%
data = pd.read_csv("input/marketing_campaign.csv", sep="\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv("/Users/elviral/work/year1/dvcode/input/marketing_campaign.csv", sep="\t")
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/elviral/work/year1/dvcode/input/marketing_campaign.csv'

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Basic Exploration</p>
#
#
# **Let's have a glimpse of the dataset.**

# %%
print(f"Shape Of The Dataset : {data.shape}")
print(f"\nGlimpse Of The Dataset :")
data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Shape Of The Dataset : (2240, 29)
#
# Glimpse Of The Dataset :
# <style type="text/css">
# #T_38b0c_row0_col0, #T_38b0c_row0_col1, #T_38b0c_row0_col2, #T_38b0c_row0_col3, #T_38b0c_row0_col4, #T_38b0c_row0_col5, #T_38b0c_row0_col6, #T_38b0c_row0_col7, #T_38b0c_row0_col8, #T_38b0c_row0_col9, #T_38b0c_row0_col10, #T_38b0c_row0_col11, #T_38b0c_row0_col12, #T_38b0c_row0_col13, #T_38b0c_row0_col14, #T_38b0c_row0_col15, #T_38b0c_row0_col16, #T_38b0c_row0_col17, #T_38b0c_row0_col18, #T_38b0c_row0_col19, #T_38b0c_row0_col20, #T_38b0c_row0_col21, #T_38b0c_row0_col22, #T_38b0c_row0_col23, #T_38b0c_row0_col24, #T_38b0c_row0_col25, #T_38b0c_row0_col26, #T_38b0c_row0_col27, #T_38b0c_row0_col28, #T_38b0c_row1_col0, #T_38b0c_row1_col1, #T_38b0c_row1_col2, #T_38b0c_row1_col3, #T_38b0c_row1_col4, #T_38b0c_row1_col5, #T_38b0c_row1_col6, #T_38b0c_row1_col7, #T_38b0c_row1_col8, #T_38b0c_row1_col9, #T_38b0c_row1_col10, #T_38b0c_row1_col11, #T_38b0c_row1_col12, #T_38b0c_row1_col13, #T_38b0c_row1_col14, #T_38b0c_row1_col15, #T_38b0c_row1_col16, #T_38b0c_row1_col17, #T_38b0c_row1_col18, #T_38b0c_row1_col19, #T_38b0c_row1_col20, #T_38b0c_row1_col21, #T_38b0c_row1_col22, #T_38b0c_row1_col23, #T_38b0c_row1_col24, #T_38b0c_row1_col25, #T_38b0c_row1_col26, #T_38b0c_row1_col27, #T_38b0c_row1_col28, #T_38b0c_row2_col0, #T_38b0c_row2_col1, #T_38b0c_row2_col2, #T_38b0c_row2_col3, #T_38b0c_row2_col4, #T_38b0c_row2_col5, #T_38b0c_row2_col6, #T_38b0c_row2_col7, #T_38b0c_row2_col8, #T_38b0c_row2_col9, #T_38b0c_row2_col10, #T_38b0c_row2_col11, #T_38b0c_row2_col12, #T_38b0c_row2_col13, #T_38b0c_row2_col14, #T_38b0c_row2_col15, #T_38b0c_row2_col16, #T_38b0c_row2_col17, #T_38b0c_row2_col18, #T_38b0c_row2_col19, #T_38b0c_row2_col20, #T_38b0c_row2_col21, #T_38b0c_row2_col22, #T_38b0c_row2_col23, #T_38b0c_row2_col24, #T_38b0c_row2_col25, #T_38b0c_row2_col26, #T_38b0c_row2_col27, #T_38b0c_row2_col28, #T_38b0c_row3_col0, #T_38b0c_row3_col1, #T_38b0c_row3_col2, #T_38b0c_row3_col3, #T_38b0c_row3_col4, #T_38b0c_row3_col5, #T_38b0c_row3_col6, #T_38b0c_row3_col7, #T_38b0c_row3_col8, #T_38b0c_row3_col9, #T_38b0c_row3_col10, #T_38b0c_row3_col11, #T_38b0c_row3_col12, #T_38b0c_row3_col13, #T_38b0c_row3_col14, #T_38b0c_row3_col15, #T_38b0c_row3_col16, #T_38b0c_row3_col17, #T_38b0c_row3_col18, #T_38b0c_row3_col19, #T_38b0c_row3_col20, #T_38b0c_row3_col21, #T_38b0c_row3_col22, #T_38b0c_row3_col23, #T_38b0c_row3_col24, #T_38b0c_row3_col25, #T_38b0c_row3_col26, #T_38b0c_row3_col27, #T_38b0c_row3_col28, #T_38b0c_row4_col0, #T_38b0c_row4_col1, #T_38b0c_row4_col2, #T_38b0c_row4_col3, #T_38b0c_row4_col4, #T_38b0c_row4_col5, #T_38b0c_row4_col6, #T_38b0c_row4_col7, #T_38b0c_row4_col8, #T_38b0c_row4_col9, #T_38b0c_row4_col10, #T_38b0c_row4_col11, #T_38b0c_row4_col12, #T_38b0c_row4_col13, #T_38b0c_row4_col14, #T_38b0c_row4_col15, #T_38b0c_row4_col16, #T_38b0c_row4_col17, #T_38b0c_row4_col18, #T_38b0c_row4_col19, #T_38b0c_row4_col20, #T_38b0c_row4_col21, #T_38b0c_row4_col22, #T_38b0c_row4_col23, #T_38b0c_row4_col24, #T_38b0c_row4_col25, #T_38b0c_row4_col26, #T_38b0c_row4_col27, #T_38b0c_row4_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_38b0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38b0c_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_38b0c_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_38b0c_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_38b0c_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_38b0c_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_38b0c_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_38b0c_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_38b0c_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_38b0c_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_38b0c_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_38b0c_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_38b0c_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_38b0c_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_38b0c_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_38b0c_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_38b0c_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_38b0c_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_38b0c_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_38b0c_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_38b0c_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_38b0c_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_38b0c_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_38b0c_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_38b0c_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_38b0c_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_38b0c_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_38b0c_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_38b0c_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_38b0c_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38b0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38b0c_row0_col0" class="data row0 col0" >5524</td>
#       <td id="T_38b0c_row0_col1" class="data row0 col1" >1957</td>
#       <td id="T_38b0c_row0_col2" class="data row0 col2" >Graduation</td>
#       <td id="T_38b0c_row0_col3" class="data row0 col3" >Single</td>
#       <td id="T_38b0c_row0_col4" class="data row0 col4" >58138.000000</td>
#       <td id="T_38b0c_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_38b0c_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_38b0c_row0_col7" class="data row0 col7" >04-09-2012</td>
#       <td id="T_38b0c_row0_col8" class="data row0 col8" >58</td>
#       <td id="T_38b0c_row0_col9" class="data row0 col9" >635</td>
#       <td id="T_38b0c_row0_col10" class="data row0 col10" >88</td>
#       <td id="T_38b0c_row0_col11" class="data row0 col11" >546</td>
#       <td id="T_38b0c_row0_col12" class="data row0 col12" >172</td>
#       <td id="T_38b0c_row0_col13" class="data row0 col13" >88</td>
#       <td id="T_38b0c_row0_col14" class="data row0 col14" >88</td>
#       <td id="T_38b0c_row0_col15" class="data row0 col15" >3</td>
#       <td id="T_38b0c_row0_col16" class="data row0 col16" >8</td>
#       <td id="T_38b0c_row0_col17" class="data row0 col17" >10</td>
#       <td id="T_38b0c_row0_col18" class="data row0 col18" >4</td>
#       <td id="T_38b0c_row0_col19" class="data row0 col19" >7</td>
#       <td id="T_38b0c_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_38b0c_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_38b0c_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_38b0c_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_38b0c_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_38b0c_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_38b0c_row0_col26" class="data row0 col26" >3</td>
#       <td id="T_38b0c_row0_col27" class="data row0 col27" >11</td>
#       <td id="T_38b0c_row0_col28" class="data row0 col28" >1</td>
#     </tr>
#     <tr>
#       <th id="T_38b0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38b0c_row1_col0" class="data row1 col0" >2174</td>
#       <td id="T_38b0c_row1_col1" class="data row1 col1" >1954</td>

# %%
print(f"Informations Of The Dataset :\n")
print(data.info())
# Out:
# Informations Of The Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Complain             2240 non-null   int64
#  26  Z_CostContact        2240 non-null   int64
#  27  Z_Revenue            2240 non-null   int64
#  28  Response             2240 non-null   int64
# dtypes: float64(1), int64(25), object(3)
# memory usage: 507.6+ KB
# None

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Dataset Summary</p>

# %%
print(f"Summary Of The Dataset :")
data.describe().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})

# 统计描述的美化输出：
# 使用 .describe() 方法获取数据集中分类数据（object 类型）的统计描述，
# 并通过 .style.set_properties() 设置输出的样式，目的是在 Jupyter Notebook 中美化展示。
# Out:
# Summary Of The Dataset :
# <style type="text/css">
# #T_e3a02_row0_col0, #T_e3a02_row0_col1, #T_e3a02_row0_col2, #T_e3a02_row0_col3, #T_e3a02_row0_col4, #T_e3a02_row0_col5, #T_e3a02_row0_col6, #T_e3a02_row0_col7, #T_e3a02_row0_col8, #T_e3a02_row0_col9, #T_e3a02_row0_col10, #T_e3a02_row0_col11, #T_e3a02_row0_col12, #T_e3a02_row0_col13, #T_e3a02_row0_col14, #T_e3a02_row0_col15, #T_e3a02_row0_col16, #T_e3a02_row0_col17, #T_e3a02_row0_col18, #T_e3a02_row0_col19, #T_e3a02_row0_col20, #T_e3a02_row0_col21, #T_e3a02_row0_col22, #T_e3a02_row0_col23, #T_e3a02_row0_col24, #T_e3a02_row0_col25, #T_e3a02_row1_col0, #T_e3a02_row1_col1, #T_e3a02_row1_col2, #T_e3a02_row1_col3, #T_e3a02_row1_col4, #T_e3a02_row1_col5, #T_e3a02_row1_col6, #T_e3a02_row1_col7, #T_e3a02_row1_col8, #T_e3a02_row1_col9, #T_e3a02_row1_col10, #T_e3a02_row1_col11, #T_e3a02_row1_col12, #T_e3a02_row1_col13, #T_e3a02_row1_col14, #T_e3a02_row1_col15, #T_e3a02_row1_col16, #T_e3a02_row1_col17, #T_e3a02_row1_col18, #T_e3a02_row1_col19, #T_e3a02_row1_col20, #T_e3a02_row1_col21, #T_e3a02_row1_col22, #T_e3a02_row1_col23, #T_e3a02_row1_col24, #T_e3a02_row1_col25, #T_e3a02_row2_col0, #T_e3a02_row2_col1, #T_e3a02_row2_col2, #T_e3a02_row2_col3, #T_e3a02_row2_col4, #T_e3a02_row2_col5, #T_e3
row6_col11, #T_e3a02_row6_col12, #T_e3a02_row6_col13, #T_e3a02_row6_col14, #T_e3a02_row6_col15, #T_e3a02_row6_col16, #T_e3a02_row6_col17, #T_e3a02_row6_col18, #T_e3a02_row6_col19, #T_e3a02_row6_col20, #T_e3a02_row6_col21, #T_e3a02_row6_col22, #T_e3a02_row6_col23, #T_e3a02_row6_col24, #T_e3a02_row6_col25, #T_e3a02_row7_col0, #T_e3a02_row7_col1, #T_e3a02_row7_col2, #T_e3a02_row7_col3, #T_e3a02_row7_col4, #T_e3a02_row7_col5, #T_e3a02_row7_col6, #T_e3a02_row7_col7, #T_e3a02_row7_col8, #T_e3a02_row7_col9, #T_e3a02_row7_col10, #T_e3a02_row7_col11, #T_e3a ...
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_e3a02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3a02_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_e3a02_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_e3a02_level0_col2" class="col_heading level0 col2" >Income</th>
#       <th id="T_e3a02_level0_col3" class="col_heading level0 col3" >Kidhome</th>
#       <th id="T_e3a02_level0_col4" class="col_heading level0 col4" >Teenhome</th>
#       <th id="T_e3a02_level0_col5" class="col_heading level0 col5" >Recency</th>
#       <th id="T_e3a02_level0_col6" class="col_heading level0 col6" >MntWines</th>
#       <th id="T_e3a02_level0_col7" class="col_heading level0 col7" >MntFruits</th>
#       <th id="T_e3a02_level0_col8" class="col_heading level0 col8" >MntMeatProducts</th>
#       <th id="T_e3a02_level0_col9" class="col_heading level0 col9" >MntFishProducts</th>
#       <th id="T_e3a02_level0_col10" class="col_heading level0 col10" >MntSweetProducts</th>
#       <th id="T_e3a02_level0_col11" class="col_heading level0 col11" >MntGoldProds</th>
#       <th id="T_e3a02_level0_col12" class="col_heading level0 col12" >NumDealsPurchases</th>
#       <th id="T_e3a02_level0_col13" class="col_heading level0 col13" >NumWebPurchases</th>
#       <th id="T_e3a02_level0_col14" class="col_heading level0 col14" >NumCatalogPurchases</th>
#       <th id="T_e3a02_level0_col15" class="col_heading level0 col15" >NumStorePurchases</th>
#       <th id="T_e3a02_level0_col16" class="col_heading level0 col16" >NumWebVisitsMonth</th>
#       <th id="T_e3a02_level0_col17" class="col_heading level0 col17" >AcceptedCmp3</th>
#       <th id="T_e3a02_level0_col18" class="col_heading level0 col18" >AcceptedCmp4</th>
#       <th id="T_e3a02_level0_col19" class="col_heading level0 col19" >AcceptedCmp5</th>
#       <th id="T_e3a02_level0_col20" class="col_heading level0 col20" >AcceptedCmp1</th>
#       <th id="T_e3a02_level0_col21" class="col_heading level0 col21" >AcceptedCmp2</th>
#       <th id="T_e3a02_level0_col22" class="col_heading level0 col22" >Complain</th>
#       <th id="T_e3a02_level0_col23" class="col_heading level0 col23" >Z_CostContact</th>
#       <th id="T_e3a02_level0_col24" class="col_heading level0 col24" >Z_Revenue</th>
#       <th id="T_e3a02_level0_col25" class="col_heading level0 col25" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3a02_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e3a02_row0_col0" class="data row0 col0" >2240.000000</td>
#       <td id="T_e3a02_row0_col1" class="data row0 col1" >2240.000000</td>
#       <td id="T_e3a02_row0_col2" class="data row0 col2" >2216.000000</td>
#       <td id="T_e3a02_row0_col3" class="data row0 col3" >2240.000000</td>
#       <td id="T_e3a02_row0_col4" class="data row0 col4" >2240.000000</td>
#       <td id="T_e3a02_row0_col5" class="data row0 col5" >2240.000000</td>
#       <td id="T_e3a02_row0_col6" class="data row0 col6" >2240.000000</td>
#       <td id="T_e3a02_row0_col7" class="data row0 col7" >2240.000000</td>
#       <td id="T_e3a02_row0_col8" class="data row0 col8" >2240.000000</td>
#       <td id="T_e3a02_row0_col9" class="data row0 col9" >2240.000000</td>
#       <td id="T_e3a02_row0_col10" class="data row0 col10" >2240.000000</td>
#       <td id="T_e3a02_row0_col11" class="data row0 col11" >2240.000000</td>
#       <td id="T_e3a02_row0_col12" class="data row0 col12" >2240.000000</td>
#       <td id="T_e3a02_row0_col13" class="data row0 col13" >2240.000000</td>
#       <td id="T_e3a02_row0_col14" class="data row0 col14" >2240.000000</td>
#       <td id="T_e3a02_r

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_a57bb_row0_col0, #T_a57bb_row0_col1, #T_a57bb_row0_col2, #T_a57bb_row0_col3, #T_a57bb_row1_col0, #T_a57bb_row1_col1, #T_a57bb_row1_col2, #T_a57bb_row1_col3, #T_a57bb_row2_col0, #T_a57bb_row2_col1, #T_a57bb_row2_col2, #T_a57bb_row2_col3 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_a57bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a57bb_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a57bb_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_a57bb_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_a57bb_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a57bb_level0_row0" class="row_heading level0 row0" >Education</th>
#       <td id="T_a57bb_row0_col0" class="data row0 col0" >2240</td>
#       <td id="T_a57bb_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_a57bb_row0_col2" class="data row0 col2" >Graduation</td>
#       <td id="T_a57bb_row0_col3" class="data row0 col3" >1127</td>
#     </tr>
#     <tr>
#       <th id="T_a57bb_level0_row1" class="row_heading level0 row1" >Marital_Status</th>
#       <td id="T_a57bb_row1_col0" class="data row1 col0" >2240</td>
#       <td id="T_a57bb_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_a57bb_row1_col2" class="data row1 col2" >Married</td>
#       <td id="T_a57bb_row1_col3" class="data row1 col3" >864</td>
#     </tr>
#     <tr>
#       <th id="T_a57bb_level0_row2" class="row_heading level0 row2" >Dt_Customer</th>
#       <td id="T_a57bb_row2_col0" class="data row2 col0" >2240</td>
#       <td id="T_a57bb_row2_col1" class="data row2 col1" >663</td>
#       <td id="T_a57bb_row2_col2" class="data row2 col2" >31-08-2012</td>
#       <td id="T_a57bb_row2_col3" class="data row2 col3" >12</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f"Null values of the Dataset :")
data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# 使用 data.isna().sum() 计算每列的缺失值数量，并以表格的形式显示。
# 删除数据中的缺失值行（dropna()），并在删除之后再次检查数据集的形状和剩余的缺失值。
# Out:
# Null values of the Dataset :
# <style type="text/css">
# #T_be07e_row0_col0, #T_be07e_row0_col1, #T_be07e_row0_col2, #T_be07e_row0_col3, #T_be07e_row0_col4, #T_be07e_row0_col5, #T_be07e_row0_col6, #T_be07e_row0_col7, #T_be07e_row0_col8, #T_be07e_row0_col9, #T_be07e_row0_col10, #T_be07e_row0_col11, #T_be07e_row0_col12, #T_be07e_row0_col13, #T_be07e_row0_col14, #T_be07e_row0_col15, #T_be07e_row0_col16, #T_be07e_row0_col17, #T_be07e_row0_col18, #T_be07e_row0_col19, #T_be07e_row0_col20, #T_be07e_row0_col21, #T_be07e_row0_col22, #T_be07e_row0_col23, #T_be07e_row0_col24, #T_be07e_row0_col25, #T_be07e_row0_col26, #T_be07e_row0_col27, #T_be07e_row0_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_be07e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be07e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_be07e_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_be07e_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_be07e_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_be07e_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_be07e_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_be07e_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_be07e_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_be07e_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_be07e_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_be07e_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_be07e_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_be07e_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_be07e_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_be07e_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_be07e_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_be07e_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_be07e_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_be07e_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_be07e_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_be07e_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_be07e_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_be07e_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_be07e_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_be07e_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_be07e_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_be07e_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_be07e_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_be07e_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be07e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be07e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_be07e_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_be07e_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_be07e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_be07e_row0_col4" class="data row0 col4" >24</td>
#       <td id="T_be07e_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_be07e_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_be07e_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_be07e_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_be07e_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_be07e_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_be07e_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_be07e_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_be07e_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_be07e_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_be07e_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_be07e_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_be07e_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_be07e_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_be07e_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_be07e_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_be07e_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_be07e_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_be07e_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_be07e_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_be07e_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_be07e_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_be07e_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_be07e_row0_col28" class="data row0 col28" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Insights:**
#
# * There are missing values in **Income**. We will drop the rows that have missing income values.
# * **Dt_Customer** that indicates the date a customer joined in this dataset is not parsed as DateTime.
# * We will encode the categorical features into numerical form later.

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Data Preprocessing</p>

# %%
data.dropna(axis = 0, inplace = True)
print(f"After dropping null values, the shape of the Dataset is {data.shape}")
print(f"After dropping null values, null values of the Dataset :")
data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After dropping null values, the shape of the Dataset is (2216, 29)
# After dropping null values, null values of the Dataset :
# <style type="text/css">
# #T_9a743_row0_col0, #T_9a743_row0_col1, #T_9a743_row0_col2, #T_9a743_row0_col3, #T_9a743_row0_col4, #T_9a743_row0_col5, #T_9a743_row0_col6, #T_9a743_row0_col7, #T_9a743_row0_col8, #T_9a743_row0_col9, #T_9a743_row0_col10, #T_9a743_row0_col11, #T_9a743_row0_col12, #T_9a743_row0_col13, #T_9a743_row0_col14, #T_9a743_row0_col15, #T_9a743_row0_col16, #T_9a743_row0_col17, #T_9a743_row0_col18, #T_9a743_row0_col19, #T_9a743_row0_col20, #T_9a743_row0_col21, #T_9a743_row0_col22, #T_9a743_row0_col23, #T_9a743_row0_col24, #T_9a743_row0_col25, #T_9a743_row0_col26, #T_9a743_row0_col27, #T_9a743_row0_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_9a743">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a743_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_9a743_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_9a743_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_9a743_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_9a743_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_9a743_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_9a743_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_9a743_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_9a743_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_9a743_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_9a743_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_9a743_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_9a743_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_9a743_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_9a743_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_9a743_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_9a743_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_9a743_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_9a743_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_9a743_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_9a743_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_9a743_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_9a743_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_9a743_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_9a743_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_9a743_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_9a743_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_9a743_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_9a743_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a743_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a743_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9a743_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_9a743_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_9a743_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9a743_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9a743_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_9a743_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_9a743_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_9a743_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_9a743_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_9a743_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_9a743_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_9a743_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_9a743_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_9a743_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_9a743_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_9a743_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_9a743_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_9a743_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_9a743_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_9a743_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_9a743_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_9a743_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_9a743_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_9a743_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_9a743_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_9a743_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_9a743_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_9a743_row0_col28" class="data row0 col28" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(data.columns)
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')

# %%
# 确保将日期列转换为日期时间格式，并指定 `dayfirst=True` 以避免格式错误
data["Dt_Customer"] = pd.to_datetime(data["Dt_Customer"], dayfirst=True, errors='coerce')

# 使用日期时间列的 `date` 属性直接提取日期
dates = data["Dt_Customer"].dt.date

# 找出最新和最早的入职日期，忽略 NaT 值
newest = max(dates.dropna())
oldest = min(dates.dropna())

print(f"Newest customer's enrolment date is {newest}")
print(f"Oldest customer's enrolment date is {oldest}")

# 使用最新日期计算客户忠诚度天数，忽略 NaT
days = [(newest - i).days if pd.notnull(i) else pd.NaT for i in dates]

# 将天数作为新列赋值给数据框
data["Customer Loyalty"] = days

# 计算客户年龄
data["Age"] = 2015 - data["Year_Birth"]

# 计算总消费金额
data["Spent"] = (
    data["MntWines"] + data["MntFruits"] + data["MntMeatProducts"] + 
    data["MntFishProducts"] + data["MntSweetProducts"] + data["MntGoldProds"]
)

# 计算孩子的总数和父母状态
data["Children"] = data["Kidhome"] + data["Teenhome"]
data["Parental Status"] = np.where(data["Children"] > 0, 1, 0)

# 替换婚姻状态和教育背景的值
data["Marital_Status"].replace({
    "Married": "Relationship", 
    "Together": "Relationship", 
    "Absurd": "Alone", 
    "Widow": "Alone", 
    "YOLO": "Alone", 
    "Divorced": "Alone", 
    "Single": "Alone"
}, inplace=True)

data["Education"].replace({
    "Basic": "Undergraduate",
    "2n Cycle": "Undergraduate", 
    "Graduation": "Graduate", 
    "Master": "Postgraduate", 
    "PhD": "Postgraduate"
}, inplace=True)

# 计算总促销接受次数
data["Total Promo"] = (
    data["AcceptedCmp1"] + data["AcceptedCmp2"] + 
    data["AcceptedCmp3"] + data["AcceptedCmp4"] + data["AcceptedCmp5"]
)

# 计算网络参与度
data["Web Engagement"] = data["NumWebVisitsMonth"] + data["NumWebPurchases"]

# 重命名一些列名
data.rename(columns={
    "Marital_Status": "Marital Status",
    "MntWines": "Wines",
    "MntFruits": "Fruits",
    "MntMeatProducts": "Meat",
    "MntFishProducts": "Fish",
    "MntSweetProducts": "Sweets",
    "MntGoldProds": "Gold",
    "NumWebPurchases": "Web",
    "NumCatalogPurchases": "Catalog",
    "NumStorePurchases": "Store",
    "NumDealsPurchases": "Discount Purchases"
}, inplace=True)

# 选择感兴趣的列
data = data[[
    "ID", "Age", "Education", "Marital Status", "Parental Status", "Children",
    "Income", "Spent", "Customer Loyalty", "Recency",
    "Wines", "Fruits", "Meat", "Fish", "Sweets", "Gold", "Web", "Catalog",
    "Store", "Discount Purchases", "Total Promo", "Web Engagement"
]]

# 过滤不合理的年龄和收入
data = data[data["Age"] < 90]
data = data[data["Income"] < 600000]
# Out:
# Newest customer's enrolment date is 2014-06-29
# Oldest customer's enrolment date is 2012-07-30

# %%
print("After preprocessing, let's have a glimpse of the final dataset :")
data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After preprocessing, let's have a glimpse of the final dataset :
# <style type="text/css">
# #T_3839a_row0_col0, #T_3839a_row0_col1, #T_3839a_row0_col2, #T_3839a_row0_col3, #T_3839a_row0_col4, #T_3839a_row0_col5, #T_3839a_row0_col6, #T_3839a_row0_col7, #T_3839a_row0_col8, #T_3839a_row0_col9, #T_3839a_row0_col10, #T_3839a_row0_col11, #T_3839a_row0_col12, #T_3839a_row0_col13, #T_3839a_row0_col14, #T_3839a_row0_col15, #T_3839a_row0_col16, #T_3839a_row0_col17, #T_3839a_row0_col18, #T_3839a_row0_col19, #T_3839a_row0_col20, #T_3839a_row0_col21, #T_3839a_row1_col0, #T_3839a_row1_col1, #T_3839a_row1_col2, #T_3839a_row1_col3, #T_3839a_row1_col4, #T_3839a_row1_col5, #T_3839a_row1_col6, #T_3839a_row1_col7, #T_3839a_row1_col8, #T_3839a_row1_col9, #T_3839a_row1_col10, #T_3839a_row1_col11, #T_3839a_row1_col12, #T_3839a_row1_col13, #T_3839a_row1_col14, #T_3839a_row1_col15, #T_3839a_row1_col16, #T_3839a_row1_col17, #T_3839a_row1_col18, #T_3839a_row1_col19, #T_3839a_row1_col20, #T_3839a_row1_col21, #T_3839a_row2_col0, #T_3839a_row2_col1, #T_3839a_row2_col2, #T_3839a_row2_col3, #T_3839a_row2_col4, #T_3839a_row2_col5, #T_3839a_row2_col6, #T_3839a_row2_col7, #T_3839a_row2_col8, #T_3839a_row2_col9, #T_3839a_row2_col10, #T_3839a_row2_col11, #T_3839a_row2_col12, #T_3839a_row2_col13, #T_3839a_row2_col14, #T_3839a_row2_col15, #T_3839a_row2_col16, #T_3839a_row2_col17, #T_3839a_row2_col18, #T_3839a_row2_col19, #T_3839a_row2_col20, #T_3839a_row2_col21, #T_3839a_row3_col0, #T_3839a_row3_col1, #T_3839a_row3_col2, #T_3839a_row3_col3, #T_3839a_row3_col4, #T_3839a_row3_col5, #T_3839a_row3_col6, #T_3839a_row3_col7, #T_3839a_row3_col8, #T_3839a_row3_col9, #T_3839a_row3_col10, #T_3839a_row3_col11, #T_3839a_row3_col12, #T_3839a_row3_col13, #T_3839a_row3_col14, #T_3839a_row3_col15, #T_3839a_row3_col16, #T_3839a_row3_col17, #T_3839a_row3_col18, #T_3839a_row3_col19, #T_3839a_row3_col20, #T_3839a_row3_col21, #T_3839a_row4_col0, #T_3839a_row4_col1, #T_3839a_row4_col2, #T_3839a_row4_col3, #T_3839a_row4_col4, #T_3839a_row4_col5, #T_3839a_row4_col6, #T_3839a_row4_col7, #T_3839a_row4_col8, #T_3839a_row4_col9, #T_3839a_row4_col10, #T_3839a_row4_col11, #T_3839a_row4_col12, #T_3839a_row4_col13, #T_3839a_row4_col14, #T_3839a_row4_col15, #T_3839a_row4_col16, #T_3839a_row4_col17, #T_3839a_row4_col18, #T_3839a_row4_col19, #T_3839a_row4_col20, #T_3839a_row4_col21 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_3839a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3839a_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_3839a_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_3839a_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_3839a_level0_col3" class="col_heading level0 col3" >Marital Status</th>
#       <th id="T_3839a_level0_col4" class="col_heading level0 col4" >Parental Status</th>
#       <th id="T_3839a_level0_col5" class="col_heading level0 col5" >Children</th>
#       <th id="T_3839a_level0_col6" class="col_heading level0 col6" >Income</th>
#       <th id="T_3839a_level0_col7" class="col_heading level0 col7" >Spent</th>
#       <th id="T_3839a_level0_col8" class="col_heading level0 col8" >Customer Loyalty</th>
#       <th id="T_3839a_level0_col9" class="col_heading level0 col9" >Recency</th>
#       <th id="T_3839a_level0_col10" class="col_heading level0 col10" >Wines</th>
#       <th id="T_3839a_level0_col11" class="col_heading level0 col11" >Fruits</th>
#       <th id="T_3839a_level0_col12" class="col_heading level0 col12" >Meat</th>
#       <th id="T_3839a_level0_col13" class="col_heading level0 col13" >Fish</th>
#       <th id="T_3839a_level0_col14" class="col_heading level0 col14" >Sweets</th>
#       <th id="T_3839a_level0_col15" class="col_heading level0 col15" >Gold</th>
#       <th id="T_3839a_level0_col16" class="col_heading level0 col16" >Web</th>
#       <th id="T_3839a_level0_col17" class="col_heading level0 col17" >Catalog</th>
#       <th id="T_3839a_level0_col18" class="col_heading level0 col18" >Store</th>
#       <th id="T_3839a_level0_col19" class="col_heading level0 col19" >Discount Purchases</th>
#       <th id="T_3839a_level0_col20" class="col_heading level0 col20" >Total Promo</th>
#       <th id="T_3839a_level0_col21" class="col_heading level0 col21" >Web Engagement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3839a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3839a_row0_col0" class="data row0 col0" >5524</td>
#       <td id="T_3839a_row0_col1" class="data row0 col1" >58</td>
#       <td id="T_3839a_row0_col2" class="data row0 col2" >Graduate</td>
#       <td id="T_3839a_row0_col3" class="data row0 col3" >Alone</td>
#       <td id="T_3839a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3839a_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_3839a_row0_col6" class="data row0 col6" >58138.000000</td>
#       <td id="T_3839a_row0_col7" class="data row0 col7" >1617</td>
#       <td id="T_3839a_row0_col8" class="data row0 col8" >663</td>
#       <td id="T_3839a_row0_col9" class="data row0 col9" >58</td>
#       <td id="T_3839a_row0_col10" class="data row0 col10" >635</td>
#       <td id="T_3839a_row0_col11" class="data row0 col11" >88</td>
#       <td id="T_3839a_row0_col12" class="data row0 col12" >546</td>
#       <td id="T_3839a_row0_col13" class="data row0 col13" >172</td>
#       <td id="T_3839a_row0_col14" class="data row0 col14" >88</td>
#       <td id="T_3839a_row0_col15" class="data row0 col15" >88</td>
#       <td id="T_3839a_row0_col16" class="data row0 col16" >8</td>
#       <td id="T_3839a_row0_col17" class="data row0 col17" >10</td>
#       <td id="T_3839a_row0_col18" class="data row0 col18" >4</td>
#       <td id="T_3839a_row0_col19" class="data row0 col19" >3</td>
#       <td id="T_3839a_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_3839a_row0_col21" class="data row0 col21" >15</td>
#     </tr>
#     <tr>
#       <th id="T_3839a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3839a_row1_col0" class="data row1 col0" >2174</td>
#       <td id="T_3839a_row1_col1" class="data row1 col1" >61</td>
#       <td id="T_3839a_row1_col2" class="data row1 col2" >Graduate</td>
#       <td id="T_3839a_row1_col3" class="data row1 col3" >Alone</td>
#       <td id="T_3839a_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_3839a_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_3839a_row1_col6" class="data row1 col6" >46344.000000</td>
#       <td id="T_3839a_row1_col7" class="data row1 col7" >27</td>
#       <td id="T_3839a_row1_col8" class="data row1 col8" >113</td>
#       <td id="T_3839a_row1_col9" class="data row1 col9" >38</td>
#       <td id="T_3839a_row1_col10" class="data row1 col10" >11</td>
#       <td id="T_3839a_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_3839a_row1_col12" class="data row1 col12" >6</td>
#       <td id="T_3839a_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_3839a_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_3839a_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_3839a_row1_col16" class="data row1 col16" >1</td>
#       <td id="T_3839a_row1_col17" class="data row1 col17" >1</td>
#       <td id="T_3839a_row1_col18" class="data row1 col18" >2</td>
#       <td id="T_3839a_row1_col19" class="data row1 col19" >2</td>
#       <td id="T_3839a_row1_col20" class="data row1 col20" >0</td>
#       <td id="T_3839a_row1_col21" class="data row1 col21" >6</td>
#     </tr>
#     <tr>
#       <th id="T_3839a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3839a_row2_col0" class="data row2 col0" >4141</td>
#       <td id="T_3839a_row2_col1" class="data row2 col1" >50</td>
#       <td id="T_3839a_row2_col2" class="data row2 col2" >Graduate</td>
#       <td id="T_3839a_row2_col3" class="data row2 col3" >Relationship</td>
#       <td id="T_3839a_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_3839a_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_3839a_row2_col6" class="data row2 col6" >71613.000000</td

# %%
print(f"After preprocessing, let's have a look on the summary of the dataset :")
data.describe().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After preprocessing, let's have a look on the summary of the dataset :
# <style type="text/css">
# #T_67083_row0_col0, #T_67083_row0_col1, #T_67083_row0_col2, #T_67083_row0_col3, #T_67083_row0_col4, #T_67083_row0_col5, #T_67083_row0_col6, #T_67083_row0_col7, #T_67083_row0_col8, #T_67083_row0_col9, #T_67083_row0_col10, #T_67083_row0_col11, #T_67083_row0_col12, #T_67083_row0_col13, #T_67083_row0_col14, #T_67083_row0_col15, #T_67083_row0_col16, #T_67083_row0_col17, #T_67083_row0_col18, #T_67083_row0_col19, #T_67083_row1_col0, #T_67083_row1_col1, #T_67083_row1_col2, #T_67083_row1_col3, #T_67083_row1_col4, #T_67083_row1_col5, #T_67083_row1_col6, #T_67083_row1_col7, #T_67083_row1_col8, #T_67083_row1_col9, #T_67083_row1_col10, #T_67083_row1_col11, #T_67083_row1_col12, #T_67083_row1_col13, #T_67083_row1_col14, #T_67083_row1_col15, #T_67083_row1_col16, #T_67083_row1_col17, #T_67083_row1_col18, #T_67083_row1_col19, #T_67083_row2_col0, #T_67083_row2_col1, #T_67083_row2_col2, #T_67083_row2_col3, #T_67083_row2_col4, #T_67083_row2_col5, #T_67083_row2_col6, #T_67083_row2_col7, #T_67083_row2_col8, #T
level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_67083_level0_col5" class="col_heading level0 col5" >Spent</th>
#       <th id="T_67083_level0_col6" class="col_heading level0 col6" >Customer Loyalty</th>
#       <th id="T_67083_level0_col7" class="col_heading level0 col7" >Recency</th>
#       <th id="T_67083_level0_col8" class="col_heading level0 col8" >Wines</th>
#       <th id="T_67083_level0_col9" class="col_heading level0 col9" >Fruits</th>
#       <th id="T_67083_level0_col10" class="col_heading level0 col10" >Meat</th>
#       <th id="T_67083_level0_col11" class="col_heading level0 col11" >Fish</th>
#       <th id="T_67083_level0_col12" class="col_heading level0 col12" >Sweets</th>
#       <th id="T_67083_level0_col13" class="col_heading level0 col13" >Gold</th>
#       <th id="T_67083_level0_col14" class="col_heading level0 col14" >Web</th>
#       <th id="T_67083_level0_col15" class="col_heading level0 col15" >Catalog</th>
#       <th id="T_67083_level0_col16" class="col_heading level0 col16" >Store</th>
#       <th id="T_67083_level0_col17" class="col_heading level0 col17" >Discount Purchases</th>
#       <th id="T_67083_level0_col18" class="col_heading level0 col18" >Total Promo</th>
#       <th id="T_67083_level0_col19" class="col_heading level0 col19" >Web Engagement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67083_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_67083_row0_col0" class="data row0 col0" >2212.000000</td>
#       <td id="T_67083_row0_col1" class="data row0 col1" >2212.000000</td>
#       <td id="T_67083_row0_col2" class="data row0 col2" >2212.000000</td>
#       <td id="T_67083_row0_col3" class="data row0 col3" >2212.000000</td>
#       <td id="T_67083_row0_col4" class="data row0 col4" >2212.000000</td>
#       <td id="T_67083_row0_col5" class="data row0 col5" >2212.000000</td>
#       <td id="T_67083_row0_col6" class="data row0 col6" >2212.000000</td>
#       <td id="T_67083_row0_col7" class="data row0 col7" >2212.000000</td>
#       <td id="T_67083_row0_col8" class="data row0 col8" >2212.000000</td>
#       <td id="T_67083_row0_col9" class="data row0 col9" >2212.000000</td>
#       <td id="T_67083_row0_col10" class="data row0 col10" >2212.000000</td>
#       <td id="T_67083_row0_col11" class="data row0 col11" >2212.000000</td>
#       <td id="T_67083_row0_col12" class="data row0 col12" >2212.000000</td>
#       <td id="T_67083_row0_col13" class="data row0 col13" >2212.000000</td>
#       <td id="T_67083_row0_col14" class="data row0 col14" >2212.000000</td>
#       <td id="T_67083_row0_col15" class="data row0 col15" >2212.000000</td>
#       <td id="T_67083_row0_col16" class="data row0 col16" >2212.000000</td>
#       <td id="T_67083_row0_col17" class="data row0 col17" >2212.000000</td>
#       <td id="T_67083_row0_col18" class="data row0 col18" >2212.000000</td>
#       <td id="T_67083_row0_col19" class="data row0 col19" >2212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_67083_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_67083_row1_col0" class="data row1 col0" >5585.160940</td>
#       <td id="T_67083_row1_col1" class="data row1 col1" >46.086347</td>
#       <td id="T_67083_row1_col2" class="data row1 col2" >0.714286</td>
#       <td id="T_67083_row1_col3" class="data row1 col3" >0.947559</td>
#       <td id="T_67083_row1_col4" class="data row1 col4" >51958.810579</td>
#       <td id="T_67083_row1_col5" class="data row1 col5" >607.268083</td>
#       <td id="T_67083_row1_col6" class="data row1 col6" >353.714286</td>
#       <td id="T_67083_row1_col7" class="data row1 col7" >49.019439</td>
#       <td id="T_67083_row1_col8" class="data row1 col8" >305.287523</td>
#       <td id="T_67083_row1_col9" class="data row1 col9" >26.329566</td>
#       <td id="T_67083_row1_col10" class="data row1 col10" >167.029837</td>
#       <td id="T_67083_row1_col11" class="data row1 col11" >37.648734</td>
#       <td id="T_67083_row1_col12" class="data row1 col12" >27.046564</td>
#       <td id="T_67083_row1_col13" class="data row1 col13" >43.925859</td>
#       <td id="T_67083_row1_col14" class="data row1 col14" >4.088156</td>
#       <td id="T_67083_row1_col15" class="data row1 col15" >2.67

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_a3e36_row0_col0, #T_a3e36_row0_col1, #T_a3e36_row0_col2, #T_a3e36_row0_col3, #T_a3e36_row1_col0, #T_a3e36_row1_col1, #T_a3e36_row1_col2, #T_a3e36_row1_col3 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_a3e36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3e36_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a3e36_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_a3e36_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_a3e36_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3e36_level0_row0" class="row_heading level0 row0" >Education</th>
#       <td id="T_a3e36_row0_col0" class="data row0 col0" >2212</td>
#       <td id="T_a3e36_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_a3e36_row0_col2" class="data row0 col2" >Graduate</td>
#       <td id="T_a3e36_row0_col3" class="data row0 col3" >1115</td>
#     </tr>
#     <tr>
#       <th id="T_a3e36_level0_row1" class="row_heading level0 row1" >Marital Status</th>
#       <td id="T_a3e36_row1_col0" class="data row1 col0" >2212</td>
#       <td id="T_a3e36_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_a3e36_row1_col2" class="data row1 col2" >Relationship</td>
#       <td id="T_a3e36_row1_col3" class="data row1 col3" >1428</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Custom Palette For Visualization</p>

# %%
sns.set_style("white")
sns.set(rc={"axes.facecolor":"#D4C8BA","figure.facecolor":"#D4C8BA"})
sns.set_context("poster",font_scale = .7)

palette = ["#101B15","#3A392B","#7A7D58","#FFF7B6","#DD9954","#94583C","#601600"]
# palette_cmap = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
palette_cmap = ["#B9C0C9","#D6B2B1","#F3AB60","#9F8A78","#9E726F","#682F2F"]
cluster = ["#B9C0C9","#682F2F","#7A7D58","#DD9954"]

sns.palplot(sns.color_palette(palette))
sns.palplot(sns.color_palette(palette_cmap))
sns.palplot(sns.color_palette(cluster))
plt.show()

#682F2F #585858

# %% [markdown]
# <a id="7"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Digging Deeper</p>

# %%
# 选择感兴趣的列进行绘图
To_Plot = ["Income", "Total Promo", "Customer Loyalty", "Age", "Spent", "Parental Status"]

# 打印信息以指示即将绘制的内容
print("Relative Plot Of Some Selected Features: A Data Subset")

# 使用 seaborn 的 pairplot 来绘制特征之间的关系
plt.figure()
sns.pairplot(data[To_Plot], hue="Parental Status", palette=(["#682F2F", "#F3AB60"]))

# 显示图形
plt.show()
# Out:
# Relative Plot Of Some Selected Features: A Data Subset

# %%
print(f"Let's have a look on the distribution of customer's age :")
plt.subplots(figsize=(20, 8))
p = sns.violinplot(data=data, x="Age", inner="quartile", color="#682F2F")
p.set_title("\nCustomer's Age Distribution\n", fontsize=25)
plt.ylabel("Density", fontsize=20)
plt.xlabel("\nAge", fontsize=20)
sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the distribution of customer's age :

# %% [markdown]
# **Insights:**
#
# * We can see it's a normal distribution of customer's age.
# * Most of the customers are from 36 to 50.

# %%
print(f"Let's have a look on the distribution of customer's income and spending :")
plt.subplots(figsize=(20, 8))
p = sns.histplot(data[["Spent","Income"]],palette=["#F3AB60","#682F2F"],kde=False,bins=30,alpha=1,fill=True,edgecolor="black")
# p.axes.lines[0].set_color(palette[0])
# p.axes.lines[1].set_color(palette[0])
p.axes.set_yscale("symlog")
p.axes.set_title("\nCustomer's Income-Spending Distribution\n",fontsize=25)
plt.ylabel("Count",fontsize=20)
plt.xlabel("\nAmount",fontsize=20)
sns.despine(left=True, bottom=True)

plt.show()
# Out:
# Let's have a look on the distribution of customer's income and spending :

# %% [markdown]
# **Insights:**
#
# * Most of the customers income range is in between 20000 to 80000
# * Bust almost all customers spend very few portion of their income.

# %% [markdown]
# **Insights:**
#
# * Customers have three education levels : Undergraduate, Graduate, Postgraduate
# * 11.39% customers are in undergraduate level, 50.41% have completed graduation and 38.2% are on postgraduation level.

# %%
# 创建一个包含两个子图的图形
fig, axes = plt.subplots(1, 2, figsize=(24, 12))

# 第一个饼图：客户的教育水平
labels_edu = ["Graduate", "Postgraduate", "Undergraduate"]
size = 0.5
wedges, texts, autotexts = axes[0].pie([data["Education"].value_counts()[0],
                                        data["Education"].value_counts()[1],
                                        data["Education"].value_counts()[2]],
                                       explode=(0, 0, 0),
                                       textprops=dict(size=20, color="white"),
                                       autopct="%.2f%%",
                                       pctdistance=0.72,
                                       radius=0.9,
                                       colors=["#682F2F", "#F3AB60", "#9F8A78"],
                                       shadow=True,
                                       wedgeprops=dict(width=size, edgecolor="black", linewidth=4),
                                       startangle=20)
axes[0].legend(wedges, labels_edu, title="Category", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1), edgecolor="black")
axes[0].set_title("Customer's Education Level", fontsize=20)

# 第二个饼图：客户的婚姻状况
labels_marital = ["Relationship", "Single"]
wedges, texts, autotexts = axes[1].pie([data["Marital Status"].value_counts()[0],
                                        data["Marital Status"].value_counts()[1]],
                                       explode=(0, 0),
                                       textprops=dict(size=20, color="white"),
                                       autopct="%.2f%%",
                                       pctdistance=0.72,
                                       radius=0.9,
                                       colors=["#682F2F", "#F3AB60"],
                                       shadow=True,
                                       wedgeprops=dict(width=size, edgecolor="black", linewidth=4),
                                       startangle=20)
axes[1].legend(wedges, labels_marital, title="Category", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1), edgecolor="black")
axes[1].set_title("Customer's Marital Status", fontsize=20)

# 调整布局并显示图形
plt.tight_layout()
plt.show()

# %%
print(f"Let's have a look on the distribution of customer's income and spending on basis of education level :")

_, axes = plt.subplots(2,1,figsize=(20,16),sharex=False)
plt.tight_layout(pad=7.0)

sns.histplot(data=data,x="Income",hue="Education",multiple="stack",palette=["#682F2F","#F3AB60","#9F8A78"],ax=axes[0],kde=False,bins=50,alpha=1,fill=True,edgecolor="black")
# axes[0].lines[0].set_color(palette[0])
# axes[0].lines[1].set_color(palette[0])
# axes[0].lines[2].set_color(palette[0])
axes[0].set_yscale("symlog")
axes[0].set_title("\nEducation Level-wise Income Distribution\n",fontsize=25)
axes[0].set_ylabel("Count",fontsize=20)
axes[0].set_xlabel("\nIncome",fontsize=20)

sns.histplot(data=data,x="Spent",hue="Education",multiple="stack",palette=["#682F2F","#F3AB60","#9F8A78"],ax=axes[1],kde=False,bins=50,alpha=1,fill=True,edgecolor="black")
# axes[1].lines[0].set_color(palette[0])
# axes[1].lines[1].set_color(palette[0])
# axes[1].lines[2].set_color(palette[0])
axes[1].set_yscale("symlog")
axes[1].set_title("\nEducation Level-wise Spending Distribution\n",fontsize=25)
axes[1].set_ylabel("Count",fontsize=20)
axes[1].set_xlabel("\nSpending",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the distribution of customer's income and spending on basis of education level :

# %% [markdown]
# **Insights:**
#
# * Most of the undergraduate level customer's income range is in between 10000 to 80000 and spending in between 0 to 1400.
# * Most of the graduate level customer's income range is in between 20000 to 85000 and spending in between 0 to 2000.
# * Most of the postgraduate level customer's income range is in between 30000 to 80000 and spending in between 0 to 2000.

# %%
print(f"Let's have a look on the distribution of customer's income and spending on basis of marital and parental status :")

_, axes = plt.subplots(2,1,figsize=(20,15),sharex=False)
plt.tight_layout(pad=6.0)

sns.swarmplot(x=data["Income"],y=data["Marital Status"],hue=data["Parental Status"],palette=["#F3AB60","#682F2F"],ax=axes[0],marker="o",size=10,alpha=1,linewidth=0.5,edgecolor="black")
axes[0].legend(["No","Yes"],title="Parent", edgecolor = "#1c1c1c",loc="center right")
axes[0].set_title("\nMarital Status-wise Income Distribution\n",fontsize=25)
axes[0].set_xlabel("\nIncome",fontsize=20)
axes[0].set_ylabel("\nMarital Status",fontsize=20)

sns.swarmplot(x=data["Spent"],y=data["Marital Status"],hue=data["Parental Status"],palette=["#F3AB60","#682F2F"],ax=axes[1],marker="o",size=10,alpha=1,linewidth=0.5,edgecolor="black")
axes[1].legend(["No","Yes"],title="Parent", edgecolor = "#1c1c1c",loc="center right")
axes[1].set_title("\nMarital Status-wise Spending Distribution\n",fontsize=25)
axes[1].set_xlabel("Spending",fontsize=20)
axes[1].set_ylabel("\nMarital Status",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the distribution of customer's income and spending on basis of marital and parental status :

# %% [markdown]
# **Insights:**
#
# * Most of the customers live together.
# * Customers who live together and are parents earn much and spend much.

# %% [markdown]
# **Insights:**
#
# * 632 customers have no child.
# * Most of the customers have one child.
# * 416 customers have two child.
# * 50 customers have three child.

# %%
print(f"Let's have a look on the distribution of customer's Income based on number of children:")

# Create a figure with subplots
_, axes = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
plt.tight_layout(pad=6.0)

# Boxplot for Spending based on Number of Children
sns.boxplot(x=data["Children"], y=data["Income"], palette=["#F3AB60", "#682F2F", "#4B3B47", "#B5B682"], ax=axes, linewidth=2.5)
axes.set_title("\nNumber of Children vs Income Distribution\n", fontsize=25)
axes.set_xlabel("\nNumber of Children", fontsize=20)
axes.set_ylabel("Income", fontsize=20)

# Remove unnecessary spines
sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the distribution of customer's Income based on number of children:

# %%
print(f"Let's have a look on the relationship between customer's income and number of children:")

# Create a figure with subplots
_, axes = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
plt.tight_layout(pad=6.0)

# Regression plot for Spending vs Number of Children
sns.regplot(x=data["Children"], y=data["Income"], ax=axes, 
            scatter_kws={"s": 80, "alpha": 0.6, "color": "#682F2F"}, 
            line_kws={"color": "#F3AB60", "linewidth": 2.5})

axes.set_title("\nRelationship between Number of Children and Income\n", fontsize=25)
axes.set_xlabel("\nNumber of Children", fontsize=20)
axes.set_ylabel("Income", fontsize=20)

# Remove unnecessary spines
sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the relationship between customer's income and number of children:

# %%
print(f"Let's have a look on the relationship between customer's income and discount purchases:")

# Create a figure with subplots
_, axes = plt.subplots(1, 1, figsize=(20, 10), sharex=False)
plt.tight_layout(pad=6.0)

# Regression plot for Discount Purchases vs Income
sns.regplot(x=data["Income"], y=data["Discount Purchases"], ax=axes, 
            scatter_kws={"s": 80, "alpha": 0.6, "color": "#682F2F"}, 
            line_kws={"color": "#F3AB60", "linewidth": 2.5})

axes.set_title("\nRelationship between Income and Discount Purchases\n", fontsize=25)
axes.set_xlabel("\nIncome", fontsize=20)
axes.set_ylabel("Number of Discount Purchases", fontsize=20)

# Remove unnecessary spines
sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the relationship between customer's income and discount purchases:

# %% [markdown]
# <a id="8"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Correlation Map</p>

# %%
catcol = ["Education","Marital Status"]
le = LabelEncoder()
for col in catcol:
        data[col] = le.fit_transform(data[col])


plt.subplots(figsize =(20, 20))

sns.heatmap(data.drop(columns="ID").corr(), cmap = palette_cmap, square=True, cbar_kws=dict(shrink =.82), 
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
plt.title("Pearson Correlation Of Features\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insights:**
#
# * High correlation between customer's income and spending. Also high correlation between buying wine, meat and buying through catalog and stores with income and spending.
# * High correlation between buying meat and buying through catalog.

# %% [markdown]
# <a id="9"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Dimensionality Reduction</p>

# %%
dataC = data.copy()
scaler = StandardScaler()
dataC = scaler.fit_transform(dataC)
scaled_data = pd.DataFrame(dataC, columns= data.columns)
print("After scaling, let's have a glimpse of the scaled dataset :")
scaled_data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After scaling, let's have a glimpse of the scaled dataset :
# <style type="text/css">
# #T_92bec_row0_col0, #T_92bec_row0_col1, #T_92bec_row0_col2, #T_92bec_row0_col3, #T_92bec_row0_col4, #T_92bec_row0_col5, #T_92bec_row0_col6, #T_92bec_row0_col7, #T_92bec_row0_col8, #T_92bec_row0_col9, #T_92bec_row0_col10, #T_92bec_row0_col11, #T_92bec_row0_col12, #T_92bec_row0_col13, #T_92bec_row0_col14, #T_92bec_row0_col15, #T_92bec_row0_col16, #T_92bec_row0_col17, #T_92bec_row0_col18, #T_92bec_row0_col19, #T_92bec_row0_col20, #T_92bec_row0_col21, #T_92bec_row1_col0, #T_92bec_row1_col1, #T_92bec_row1_col2, #T_92bec_row1_col3, #T_92bec_row1_col4, #T_92bec_row1_col5, #T_92bec_row1_col6, #T_92bec_row1_col7, #T_92bec_row1_col8, #T_92bec_row1_col9, #T_92bec_row1_col10, #T_92bec_row1_col11, #T_92bec_row1_col12, #T_92bec_row1_col13, #T_92bec_row1_col14, #T_92bec_row1_col15, #T_92bec_row1_col16, #T_92bec_row1_col17, #T_92bec_row1_col18, #T_92bec_row1_col19, #T_92bec_row1_col20, #T_92bec_row1_col21, #T_92bec_row2_col0, #T_92bec_row2_col1, #T_92bec_row2_col2, #T_92bec_row2_col3, #T_92bec_row2_col4, #T_92bec_row2_col5, #T_92bec_row2_col6, #T_92bec_row2_col7, #T_92bec_row2_col8, #T_92bec_row2_col9, #T_92bec_row2_col10, #T_92bec_row2_col11, #T_92bec_row2_col12, #T_92bec_row2_col13, #T_92bec_row2_col14, #T_92bec_row2_col15, #T_92bec_row2_col16, #T_92bec_row2_col17, #T_92bec_row2_col18, #T_92bec_row2_col19, #T_92bec_row2_col20, #T_92bec_row2_col21, #T_92bec_row3_col0, #T_92bec_row3_col1, #T_92bec_row3_col2, #T_92bec_row3_col3, #T_92bec_row3_col4, #T_92bec_row3_col5, #T_92bec_row3_col6, #T_92bec_row3_col7, #T_92bec_row3_col8, #T_92bec_row3_col9, #T_92bec_row3_col10, #T_92bec_row3_col11, #T_92bec_row3_col12, #T_92bec_row3_col13, #T_92bec_row3_col14, #T_92bec_row3_col15, #T_92bec_row3_col16, #T_92bec_row3_col17, #T_92bec_row3_col18, #T_92bec_row3_col19, #T_92bec_row3_col20, #T_92bec_row3_col21, #T_92bec_row4_col0, #T_92bec_row4_col1, #T_92bec_row4_col2, #T_92bec_row4_col3, #T_92bec_row4_col4, #T_92bec_row4_col5, #T_92bec_row4_col6, #T_92bec_row4_col7, #T_92bec_row4_col8, #T_92bec_row4_col9, #T_92bec_row4_col10, #T_92bec_row4_col11, #T_92bec_row4_col12, #T_92bec_row4_col13, #T_92bec_row4_col14, #T_92bec_row4_col15, #T_92bec_row4_col16, #T_92bec_row4_col17, #T_92bec_row4_col18, #T_92bec_row4_col19, #T_92bec_row4_col20, #T_92bec_row4_col21 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_92bec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92bec_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_92bec_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_92bec_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_92bec_level0_col3" class="col_heading level0 col3" >Marital Status</th>
#       <th id="T_92bec_level0_col4" class="col_heading level0 col4" >Parental Status</th>
#       <th id="T_92bec_level0_col5" class="col_heading level0 col5" >Children</th>
#       <th id="T_92bec_level0_col6" class="col_heading level0 col6" >Income</th>
#       <th id="T_92bec_level0_col7" class="col_heading level0 col7" >Spent</th>
#       <th id="T_92bec_level0_col8" class="col_heading level0 col8" >Customer Loyalty</th>
#       <th id="T_92bec_level0_col9" class="col_heading level0 col9" >Recency</th>
#       <th id="T_92bec_level0_col10" class="col_heading level0 col10" >Wines</th>
#       <th id="T_92bec_level0_col11" class="col_heading level0 col11" >Fruits</th>
#       <th id="T_92bec_level0_col12" class="col_heading level0 col12" >Meat</th>
#       <th id="T_92bec_level0_col13" class="col_heading level0 col13" >Fish</th>
#       <th id="T_92bec_level0_col14" class="col_heading level0 col14" >Sweets</th>
#       <th id="T_92bec_level0_col15" class="col_heading level0 col15" >Gold</th>
#       <th id="T_92bec_level0_col16" class="col_heading level0 col16" >Web</th>
#       <th id="T_92bec_level0_col17" class="col_heading level0 col17" >Catalog</th>
#       <th id="T_92bec_level0_col18" class="col_heading level0 col18" >Store</th>
#       <th id="T_92bec_level0_col19" class="col_heading level0 col19" >Discount Purchases</th>
#       <th id="T_92bec_level0_col20" class="col_heading level0 col20" >Total Promo</th>
#       <th id="T_92bec_level0_col21" class="col_heading level0 col21" >Web Engagement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92bec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92bec_row0_col0" class="data row0 col0" >-0.018837</td>
#       <td id="T_92bec_row0_col1" class="data row0 col1" >1.018352</td>
#       <td id="T_92bec_row0_col2" class="data row0 col2" >-0.893586</td>
#       <td id="T_92bec_row0_col3" class="data row0 col3" >-1.349603</td>
#       <td id="T_92bec_row0_col4" class="data row0 col4" >-1.581139</td>
#       <td id="T_92bec_row0_col5" class="data row0 col5" >-1.264598</td>
_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92bec_row2_col0" class="data row2 col0" >-0.444797</td>
#       <td id="T_92bec_row2_col1" class="data row2 col1" >0.334530</td>
#       <td id="T_92bec_row2_col2" class="data row2 col2" >-0.893586</td>

# %%
scaled_dataC = scaled_data.copy()
pca = PCA(n_components = 3,random_state = 42)
scaled_dataC = pca.fit_transform(scaled_dataC)
pca_data = pd.DataFrame(scaled_dataC, columns=["col1","col2", "col3"])

print("Let's have a glimpse of the PCA transformed dataset :")
pca_data.head(15).T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Let's have a glimpse of the PCA transformed dataset :
# <style type="text/css">
# #T_bab18_row0_col0, #T_bab18_row0_col1, #T_bab18_row0_col2, #T_bab18_row0_col3, #T_bab18_row0_col4, #T_bab18_row0_col5, #T_bab18_row0_col6, #T_bab18_row0_col7, #T_bab18_row0_col8, #T_bab18_row0_col9, #T_bab18_row0_col10, #T_bab18_row0_col11, #T_bab18_row0_col12, #T_bab18_row0_col13, #T_bab18_row0_col14, #T_bab18_row1_col0, #T_bab18_row1_col1, #T_bab18_row1_col2, #T_bab18_row1_col3, #T_bab18_row1_col4, #T_bab18_row1_col5, #T_bab18_row1_col6, #T_bab18_row1_col7, #T_bab18_row1_col8, #T_bab18_row1_col9, #T_bab18_row1_col10, #T_bab18_row1_col11, #T_bab18_row1_col12, #T_bab18_row1_col13, #T_bab18_row1_col14, #T_bab18_row2_col0, #T_bab18_row2_col1, #T_bab18_row2_col2, #T_bab18_row2_col3, #T_bab18_row2_col4, #T_bab18_row2_col5, #T_bab18_row2_col6, #T_bab18_row2_col7, #T_bab18_row2_col8, #T_bab18_row2_col9, #T_bab18_row2_col10, #T_bab18_row2_col11, #T_bab18_row2_col12, #T_bab18_row2_col13, #T_bab18_row2_col14 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_bab18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bab18_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_bab18_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_bab18_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_bab18_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_bab18_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_bab18_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_bab18_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_bab18_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_bab18_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_bab18_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_bab18_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_bab18_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_bab18_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_bab18_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_bab18_level0_col14" class="col_heading level0 col14" >14</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bab18_level0_row0" class="row_heading level0 row0" >col1</th>
#       <td id="T_bab18_row0_col0" class="data row0 col0" >4.772287</td>
#       <td id="T_bab18_row0_col1" class="data row0 col1" >-2.773383</td>
#       <td id="T_bab18_row0_col2" class="data row0 col2" >2.105845</td>
#       <td id="T_bab18_row0_col3" class="data row0 col3" >-2.648298</td>
#       <td id="T_bab18_row0_col4" class="data row0 col4" >-0.472222</td>
#       <td id="T_bab18_row0_col5" class="data row0 col5" >0.558605</td>
#       <td id="T_bab18_row0_col6" class="data row0 col6" >0.538310</td>
#       <td id="T_bab18_row0_col7" class="data row0 col7" >-2.129909</td>
#       <td id="T_bab18_row0_col8" class="data row0 col8" >-2.662302</td>
#       <td id="T_bab18_row0_col9" class="data row0 col9" >-3.315978</td>
#       <td id="T_bab18_row0_col10" class="data row0 col10" >-1.990505</td>
#       <td id="T_bab18_row0_col11" class="data row0 col11" >3.301414</td>
#       <td id="T_bab18_row0_col12" class="data row0 col12" >-1.497468</td>
#       <td id="T_bab18_row0_col13" class="data row0 col13" >-1.957015</td>
#       <td id="T_bab18_row0_col14" class="data row0 col14" >4.055031</td>
#     </tr>
#     <tr>
#       <th id="T_bab18_level0_row1" class="row_heading level0 row1" >col2</th>
#       <td id="T_bab18_row1_col0" class="data row1 col0" >0.957577</td>
#       <td id="T_bab18_row1_col1" class="data row1 col1" >-0.821555</td>
#       <td id="T_bab18_row1_col2" class="data row1 col2" >-0.015246</td>
#       <td id="T_bab18_row1_col3" class="data row1 col3" >-0.966718</td>
#       <td id="T_bab18_row1_col4" class="data row1 col4" >0.558950</td>
#       <td id="T_bab18_row1_col5" class="data row1 col5" >1.011117</td>
#       <td id="T_bab18_row1_col6" class="data row1 col6" >1.750404</td>
#       <td id="T_bab18_row1_col7" class="data row1 col7" >0.294987</td>
#       <td id="T_bab18_row1_col8" class="data row1 col8" >-0.153018</td>
#       <td id="T_bab18_row1_col9" class="data row1 col9" >1.089331</td>
#       <td id="T_bab18_row1_col10" class="data row1 col10" >-1.414136</td>
#       <td id="T_bab18_row1_col11" class="data row1 col11" >-2.528696</td>
#       <td id="T_bab18_row1_col12" class="data row1 col12" >1.382316</td>
#       <td id="T_bab18_row1_col13" class="data row1 col13" >-1.744378</td>
#       <td id="T_bab18_row1_col14" class="data row1 col14" >0.448786</td>
#     </tr>
#     <tr>
#       <th id="T_bab18_level0_row2" class="row_heading level0 row2" >col3</th>
#       <td id="T_bab18_row2_col0" class="data row2 col0" >-1.954468</td>
#       <td id="T_bab18_row2_col1" class="data row2 col1" >1.572212</td>
#       <td id="T_bab18_row2_col2" class="data row2 col2" >-0.431489</td>
#       <td id="T_bab18_row2_col3" class="data row2 col3" >-0.277370</td>
#       <td id="T_bab18_row2_col4" class="data row2 col4" >-0.029824</td>
#       <td id="T_bab18_row2_col5" class="data row2 col5" >0.609964</td>
#       <td id="T_bab18_row2_col6" class="data row2 col6" >-1.332598</td>
#       <td id="T_bab18_row2_col7" class="data row2 col7" >-1.153683</td>
#       <td id="T_bab18_row2_col8" class="data row2 col8" >-0.630727</td>
#       <td id="T_bab18_row2_col9" class="data row2 col9" >0.929461</td>
#       <td id="T_bab18_row2_col10" class="data row2 col10" >-2.076894</td>
#       <td id="T_bab18_row2_col11" class="data row2 col11" >-0.666447</td>
#       <td id="T_bab18_row2_col12" class="data row2 col12" >1.266292</td>
#       <td id="T_bab18_row2_col13" class="data row2 col13" >-2.367252</td>
#       <td id="T_bab18_row2_col14" class="data row2 col14" >1.354581</td>
#     </tr>
#   </tbody>
# </table>

# %%
x = pca_data["col1"]
y = pca_data["col2"]
z = pca_data["col3"]

print(f"Let's have a look on the dataset after dimensionality reduction :")

fig = go.Figure(data = [go.Scatter3d(x=x, y=y, z=z,mode='markers',
                marker = dict(size=10, color="#682F2F", opacity=0.8))])
fig.update_layout(title=dict(text= "Dataset After Diemsionality Reduction[3D Projection]",
                             y=0.97,x=0.5,xanchor= "center",yanchor= "top",font_color="black"),
                  scene=dict(xaxis = dict(title="col1",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white"),
                             yaxis = dict(title="col2",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white"),
                             zaxis = dict(title="col3",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white")),
                  margin=dict(l=0, r=0, b=0, t=0),paper_bgcolor="#D4C8BA")
fig.show()
# Out:
# Let's have a look on the dataset after dimensionality reduction :
# <div>                            <div id="26333024-c9b5-472d-98f9-9d7e25eb271b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
.8359952051943234,1.4479122414482548,-0.30548854595346453,3.552776443410999,-2.6490081947951096,-2.9961151578591463,-2.558851858251608,-2.249842467675443,-2.518880765954071,-1.7341096847382056,3.99416431642042,4.719962416278494,-2.9746482723477166,-3.3971978633049447,3.477178736891935,-1.8595884894126626,-2.8507464642790867,2.6076789936650315,-2.714960868850028,-1.840589877628966,-2.6617590543139884,-2.7378726268007516,0 ...

# %% [markdown]
# **N.B.** Kindly reload the notebook if you face problem to visualize this figure.

# %% [markdown]
# <a id="10"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Customer Segmentation</p>

# %%
print("Elbow Method for determining the number of clusters :")
_, axes = plt.subplots(figsize=(20,8))

elbow = KElbowVisualizer(KMeans(), k=10, timings=False, locate_elbow=True, size=(1260,450))
elbow.fit(pca_data)

axes.set_title("\nDistortion Score Elbow For KMeans Clustering\n",fontsize=25)
axes.set_xlabel("\nK",fontsize=20)
axes.set_ylabel("\nDistortion Score",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Elbow Method for determining the number of clusters :

# %% [markdown]
# **Insights:**
#
# * We will use **k = 4**, thus there will be **four clusters** in our dataset.
# * We will use **KMeans Algorithm** for clustering.

# %%
km = KMeans(n_clusters = 4,random_state = 42)
# ac = AgglomerativeClustering(n_clusters=4)

y_km = km.fit_predict(pca_data)
pca_data["Clusters"] = y_km
data["Clusters"]= y_km
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 km = KMeans(n_clusters = 4,random_state = 42)
#       2 # ac = AgglomerativeClustering(n_clusters=4)
# ----> 4 y_km = km.fit_predict(pca_data)
#       5 pca_data["Clusters"] = y_km
#       6 data["Clusters"]= y_km
#
# NameError: name 'pca_data' is not defined

# %%
print("Let's have a look on the customers quantity distribution after clustering :")

plt.subplots(figsize=(20, 8))
p = sns.countplot(x=data["Clusters"], palette=["#B9C0C9", "#682F2F", "#9F8A78", "#F3AB60", "#4E7C8C"], saturation=1, edgecolor="#1c1c1c", linewidth=4)
p.axes.set_yscale("linear")
p.axes.set_title("\nCustomer's Clusters\n", fontsize=25)
p.axes.set_ylabel("Count", fontsize=20)
p.axes.set_xlabel("\nCluster", fontsize=20)
p.axes.set_xticklabels(p.get_xticklabels(), rotation=0)
for container in p.containers:
    p.bar_label(container, label_type="center", padding=6, size=30, color="black", rotation=0,
                bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "white", "linewidth": 4, "alpha": 1})

sns.despine(left=True, bottom=True)
plt.show()

print(f"Let's have a look on the dataset after clustering :")

fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, mode='markers',
                marker=dict(size=10, color=pca_data["Clusters"], colorscale=["#B9C0C9", "#682F2F", "#9F8A78", "#F3AB60", "#4E7C8C"], opacity=1))])
fig.update_layout(title=dict(text="Dataset After Clustering[3D Projection]",
                             y=0.97, x=0.5, xanchor="center", yanchor="top", font_color="black"),
                  scene=dict(xaxis=dict(title="col1", backgroundcolor="#D4C8BA", showbackground=True, showgrid=True, gridwidth=2, gridcolor='white', zerolinecolor="white"),
                             yaxis=dict(title="col2", backgroundcolor="#D4C8BA", showbackground=True, showgrid=True, gridwidth=2, gridcolor='white', zerolinecolor="white"),
                             zaxis=dict(title="col3", backgroundcolor="#D4C8BA", showbackground=True, showgrid=True, gridwidth=2, gridcolor='white', zerolinecolor="white")),
                  margin=dict(l=0, r=0, b=0, t=0), paper_bgcolor="#D4C8BA")
fig.show()
# Out:
# Let's have a look on the customers quantity distribution after clustering :
# Let's have a look on the dataset after clustering :
# <div>                            <div id="b8f46019-0b79-412e-a5d8-59c374c93d19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b
3,2,0,4,0,1,0,4,4,0,2,0,1,4,4,4,1,1,4,4,2,3,4,3,3,3,2,3,1,2,1,3,4,4,3,0,3,3,4,2,3,4,2,4,2,1,4,2,1,1,3,1,1,1,2,2,0,0,1,3,2,0,2,0,4,3,4,1,1,1,1,2,3,4,1,4,2,0,3,1,1,1,4,0,0,2,4,2,4,0,3,1,0,4,1,3,1,2,0,3,4,4,3,3,2,0,2,1,3,3,0,2,1,3,0,2,2,0,2,0,3,0,3,2,1,2,1,3,0,3,0,3,2,0,3,2,2,0,0,0,4,3,3,0,2,1,2,3,0,4,1,0,0,4,0,1,2,3,0,0,4,4,1,1,4,0,0,1,0,3,3,2,0,1,0,4,3,0,4,1,3,2,2,0,0,2,1,2,0,0,3,4,3,2,3,3,4,0,1,1,3,0,4,4,1,2,2,2,4,1,3,1,3,0,2,0,0,0,0,0,2,3,4,2,3,2,1,1,1,4,1,2,0,4,4,0,1,3,1,1,4,3,4,0,2,4,1,2,1,3,4,0,3,4,1,2,2,2,3,1,3,1,4,4,0,1,0,2,4,4,3,2,3,0,0,3,0,2,3 ...

# %% [markdown]
# **Insights:**
#
# * Cluster 0 has 538 customers.
# * Cluster 1 has the highest amount of 599 customers.
# * Cluster 2 has 509 customers.
# * Cluster 3 has 566 customers.

# %% [markdown]
# **N.B.** Kindly reload the notebook if you face problem to visualize this figure.

# %%
print(f"Let's have a look on the characteristics of the clusters on the basis of income and spending :")

_, axes = plt.subplots(figsize=(20,8))
sns.scatterplot(x=data["Spent"], y=data["Income"], hue=data["Clusters"], palette=["#B9C0C9", "#682F2F", "#9F8A78", "#F3AB60", "#4E7C8C"], sizes=60, alpha=1, edgecolor="#1c1c1c", linewidth=1)
axes.set_title("\nIncome-Spending Basis Clustering Profile\n", fontsize=25)
axes.set_ylabel("Income", fontsize=20)
axes.set_xlabel("\nSpending", fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the characteristics of the clusters on the basis of income and spending :

# %% [markdown]
# **Insights:**
#
# * Most of the cluster 0 customers income range is in between 5000 to 40000 and spending range is in between 0 to 500.
# * Most of the cluster 1 customers income range is in between 65000 to 85000 and spending range is in between 550 to 2000.
# * Most of the cluster 2 customers income range is in between 50000 to 80000 and spending range is in between 250 to 1800.
# * Most of the cluster 3 customers income range is in between 40000 to 60000 and spending range is in between 0 to 500.

# %% [markdown]
# **Insights:**
#
# * Most of the cluster 0 customers spending range is in between 0 to 500.
# * Most of the cluster 1 customers spending range is in between 550 to 2000.
# * Most of the cluster 2 customers spending range is in between 250 to 1800.
# * Most of the cluster 3 customers spending range is in between 0 to 500.

# %%
print(f"Let's have a look on the characteristics of the clusters on the basis of accepting promotions :")

plt.subplots(figsize=(20, 8))
p = sns.countplot(x=data["Total Promo"], hue=data["Clusters"], palette=["#B9C0C9", "#682F2F", "#9F8A78", "#F3AB60", "#4E7C8C"], saturation=1, edgecolor="#1c1c1c", linewidth=2)
p.axes.set_yscale("linear")
p.axes.set_title("\nPromotions Acceptance Based Clustering Profile\n", fontsize=25)
p.axes.set_ylabel("Count", fontsize=20)
p.axes.set_xlabel("\nAccepted Promotions", fontsize=20)
p.axes.set_xticklabels(p.get_xticklabels(), rotation=0)
for container in p.containers:
    p.bar_label(container, label_type="center", padding=6, size=10, color="black", rotation=0,
                bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "white", "linewidth": 2, "alpha": 1})

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the characteristics of the clusters on the basis of accepting promotions :

# %% [markdown]
# **Insights:**
#
# * 546 customers of cluster 0, 283 customers of cluster 1, 410 customers of cluster 2 and 515 customers of cluster 3 have not accepted any promotions yet.
# * 52 customers of cluster 0, 123 customers of cluster 1, 100 customers of cluster 2 and 47 customers of cluster 3 have accepted only one promotions yet.
# * 1 customer of cluster 0, 55 customers of cluster 1, 21 customers of cluster 2 and 4 customers of cluster 3 have accepted two promotions.
# * Only 37 customers of cluster 1 and 7 customers of cluster 2 have accepted three promotions.
# * Only 11 customers of cluster 1 have accepted Four promotions.

# %%
print(f"Let's have a look on the characteristics of the clusters on the basis of discount purchases :")

_, axes = plt.subplots(figsize=(30,10))
sns.boxenplot(x=data["Clusters"], y=data["Discount Purchases"], palette=["#B9C0C9", "#682F2F", "#9F8A78", "#F3AB60", "#4E7C8C"])

axes.set_title("\nDiscount Purchase Based Clustering Profile\n", fontsize=25)
axes.set_ylabel("Discount Purchase", fontsize=20)
axes.set_xlabel("\nCluster", fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the characteristics of the clusters on the basis of discount purchases :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 have completed purchases using discount either 1/2 times.
# * Most of the customers of cluster 1 have completed purchases using discount only one times.
# * Most of the customers of cluster 2 have completed purchases using discount 2 to 5 times.
# * Most of the customers of cluster 3 have completed purchases using discount 1 to 4 times.

# %%
def cluster(feature):
    
    _, axes = plt.subplots(figsize=(20,8))
    sns.kdeplot(x=data[feature], y=data["Spent"], hue=data["Clusters"], kind="kde", height=10, palette=["#B9C0C9", "#682F2F", "#9F8A78", "#F3AB60", "#4E7C8C"])
    axes.set_title(f"\nClustering Profile On {feature}\n", fontsize=25)
    axes.set_ylabel("Spending", fontsize=20)
    axes.set_xlabel(f"\n{feature}", fontsize=20)
    
    sns.despine(left=True, bottom=True)
    plt.show()

# %%
print(f"Characteristics of clusters based on spending and having childern :")
cluster("Children")
# Out:
# Characteristics of clusters based on spending and having childern :

# %% [markdown]
# **Insights:**
#
# * Customers of cluster 0 either have one child or don't have any. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 don't have any child, only a few have one. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 have one child, some have two. Their spending range is in between 250 to 1800.
# * Most of the customers of cluster 3 have two child, some have one and very few have three. Their spending range is in between 0 to 500.

# %%
print(f"Characteristics of clusters based on spending and age :")
cluster("Age")
# Out:
# Characteristics of clusters based on spending and age :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 have age range in between 25 to 50. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 have age range in between 30 to 60. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 have age range in between 35 to 60. Their spending range is in between 250 to 1800.
# * Most of the customers of cluster 3 have age range in between 40 to 65. Their spending range is in between 0 to 500.

# %%
print(f"Characteristics of clusters based on spending and education level :")
cluster("Education")
# Out:
# Characteristics of clusters based on spending and education level :

# %% [markdown]
# **Insights:**
#
# * The customers of cluster 0 are graduate or in postgraduate level or in undergraduate level. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 are graduate or in postgraduate level. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 are graduate and very few in postgraduate level. Their spending range is in between 250 to 1800.
# * All the customers of cluster 3 are graduate or in postgraduate level and some are in undergraduate level. Their spending range is in between 0 to 500.

# %%
print(f"Characteristics of clusters based on spending and marital status :")
cluster("Marital Status")
# Out:
# Characteristics of clusters based on spending and marital status :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 are married and very few are unmarried. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 are married. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 are married. Their spending range is in between 250 to 1800.
# * Some customers of cluster 3 are married and some are unmarried. Their spending range is in between 0 to 500.

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 are parents and very few are not parents. Their spending range is in between 0 to 500.
# * All the customers of cluster 1 are not parents. Their spending range is in between 550 to 2000.
# * All the customers of cluster 2 are parents. Their spending range is in between 250 to 1800.
# * All the customers of cluster 3 are parents. Their spending range is in between 0 to 500.

# %%
print(f"Characteristics of clusters based on spending and customer loyalty :")
cluster("Customer Loyalty")
# Out:
# Characteristics of clusters based on spending and customer loyalty :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 are customer for 300 to 900 days. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 are customer for 250 to 750 days. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 are customer for 400 to 800 days. Their spending range is in between 250 to 1800.
# * Most of the customers of cluster 3 are customer for 150 to 650 days. Their spending range is in between 0 to 500.

# %% [markdown]
# <a id="11"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Customer's Cluster Profiling</p>

# %% [markdown]
# <p>
# <h3><font color="#682F2F">📌Cluster 0</font></h3>
# 👉 Income range is in between 5000 to 40000 and spending range is in between 0 to 500<br>
# 👉 Age range in between 25 to 50<br>
# 👉 From any educational level<br>
# 👉 Can be married and unmarried as well<br>
# 👉 Most of them are parents<br>
# 👉 Some have one child<br>
# 👉 Customer for at least 300 days<br>
# 👉 Promotion acceptance is rare<br>
# 👉 Very few complete purchases using discounts<br>
#
# <h3><font color="#682F2F">📌Cluster 1</font></h3>
# 👉 Income range is in between 65000 to 85000 and spending range is in between 550 to 2000<br>
# 👉 Age range in between 30 to 60<br>
# 👉 Almost all have completed graduation<br>
# 👉 Most of them are married<br>
# 👉 They are not parents<br>
# 👉 Have no child<br>
# 👉 Customer for at least 250 days<br>
# 👉 Promotion acceptance ratio is 0.5<br>
# 👉 Completing purchases using discounts are rare<br>
#
# <h3><font color="#682F2F">📌Cluster 2</font></h3>
# 👉 Income range is in between 50000 to 80000 and spending range is in between 250 to 1800<br>
# 👉 Age range in between 35 to 60<br>
# 👉 Almost all have completed graduation<br>
# 👉 Most of them are married<br>
# 👉 They are parents<br>
# 👉 All have children, most have one child<br>
# 👉 Customer for at least 400 days<br>
# 👉 Promotion acceptance ratio is poor<br>
# 👉 Highly interested in completing purchases using discounts<br>
#
# <h3><font color="#682F2F">📌Cluster 3</font></h3>
# 👉 Income range is in between 40000 to 60000 and spending range is in between 0 to 500<br>
# 👉 Age range in between 40 to 65<br>
# 👉 Almost all have completed graduation<br>
# 👉 Can be married and unmarried as well<br>
# 👉 They are parents<br>
# 👉 All have children, most have two children<br>
# 👉 Customer for at least 150 days<br>
# 👉 Promotion acceptance is rare<br>
# 👉 Highly interested in completing purchases using discounts<br>
#
# </p>

# %% [markdown]
# <a id="12"></a>
# # <p style="padding:10px;background-color:#682F2F;margin:0;color:#e9c46a;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Thank You</p>
#
#
#
# <p>
# <h3><font color="#682F2F">If you liked this notebook please upvote. Your feedback will be highly appreciated.</font></h3>
#
# <br>
#
# <h4><b>Author :</b></h4>
#
# <h3>Hasib Al Muzdadid</h3>
#
# <b>👉Shoot me mails :</b> muzdadid@gmail.com<br>
# <b>👉Connect on LinkedIn :</b> https://www.linkedin.com/in/hasibalmuzdadid <br>
# <b>👉Explore Github :</b> https://github.com/HasibAlMuzdadid
#
# </p>
